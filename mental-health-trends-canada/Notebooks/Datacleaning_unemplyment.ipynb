# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\bibis\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\bibis\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bibis\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bibis\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\bibis\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\bibis\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
import glob

def clean_csv(file_path):
    # Read the CSV file
    df = pd.read_csv(file_path)
    
    # Print column names to check for discrepancies
    print(f"Processing file: {file_path}")
    print(f"Columns: {df.columns.tolist()}")
    
    # Normalize column names to lowercase and strip leading/trailing whitespaces
    df.columns = [col.lower().strip() for col in df.columns]
    
    # Check for the presence of required columns
    if 'labour force characteristics' not in df.columns or 'statistics' not in df.columns:
        print(f"Skipping file due to missing columns: {file_path}")
        return None
    
    # Print unique values in the relevant columns to debug
    print(f"Unique values in 'labour force characteristics' column: {df['labour force characteristics'].unique()}")
    print(f"Unique values in 'statistics' column: {df['statistics'].unique()}")
    
    # Filter rows where 'labour force characteristics' or 'statistics' is 'Unemployment rate' (case-insensitive)
    df_filtered = df[
        df['labour force characteristics'].str.contains('unemployment rate', case=False, na=False) |
        df['statistics'].str.contains('unemployment rate', case=False, na=False)
    ]
    
    # Print filtered data to debug
    print(f"Filtered data for {file_path}:")
    print(df_filtered)
    
    # Select the required columns
    columns_needed = ['ref_date', 'geo', 'age group', 'gender', 'value']
    df_cleaned = df_filtered[columns_needed]
    
    # Save the cleaned data to a new CSV file
    cleaned_file_path = file_path.replace('.csv', '_cleaned.csv')
    df_cleaned.to_csv(cleaned_file_path, index=False)
    
    return cleaned_file_path

# Path to the directory containing the CSV files
csv_directory = r"C:\\Users\\bibis\\Desktop\\Dataset for capstone unemployment"

# Get a list of all CSV files in the directory
csv_files = glob.glob(csv_directory + '/*.csv')

# Process each CSV file
cleaned_files = []
for csv_file in csv_files:
    cleaned_file = clean_csv(csv_file)
    if cleaned_file:
        cleaned_files.append(cleaned_file)
    
print(f'Cleaned files: {cleaned_files}')
# Out:
# Processing file: C:\\Users\\bibis\\Desktop\\Dataset for capstone unemployment\April 2021.csv
# Columns: ['REF_DATE', 'GEO', 'DGUID', 'Labour force characteristics', 'Gender', 'Age group', 'Statistics', 'Data type', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS']
# Unique values in 'labour force characteristics' column: ['Population' 'Labour force' 'Employment' 'Full-time employment'
#  'Part-time employment' 'Unemployment' 'Unemployment rate'
#  'Participation rate' 'Employment rate']
# Unique values in 'statistics' column: ['Estimate']
# Filtered data for C:\\Users\\bibis\\Desktop\\Dataset for capstone unemployment\April 2021.csv:
#    ref_date                        geo           dguid  \
# 6   2021-04                     Canada  2021A000011124
# 15  2021-04  Newfoundland and Labrador     2021A000210
# 24  2021-04       Prince Edward Island     2021A000211
# 33  2021-04                Nova Scotia     2021A000212
# 42  2021-04              New Brunswick     2021A000213
# 51  2021-04                     Quebec     2021A000224
# 60  2021-04                    Ontario     2021A000235
# 69  2021-04                   Manitoba     2021A000246
# 78  2021-04               Saskatchewan     2021A000247
# 87  2021-04                    Alberta     2021A000248
# 96  2021-04           British Columbia     2021A000259
#
#    labour force characteristics          gender          age group statistics  \
# 6             Unemployment rate  Total - Gender  15 years and over   Estimate
# 15            Unemployment rate  Total - Gender  15 years and over   Estimate
# 24            Unemployment rate  Total - Gender  15 years and over   Estimate
# 33            Unemployment rate  Total - Gender  15 years and over   Estimate
# 42            Unemployment rate  Total - Gender  15 years and over   Estimate
# 51            Unemployment rate  Total - Gender  15 years and over   Estimate
# 60            Unemployment rate  Total - Gender  15 years and over   Estimate
# 69            Unemployment rate  Total - Gender  15 years and over   Estimate
# 78            Unemployment rate  Total - Gender  15 years and over   Estimate
# 87            Unemployment rate  Total - Gender  15 years and over   Estimate
# 96            Unemployment rate  Total - Gender  15 years and over   Estimate
#
#               data type      uom  uom_id scalar_factor  scalar_id    vector  \
# 6   Seasonally adjusted  Percent     239         units          0  v2062815
# 15  Seasonally adjusted  Percent     239         units          0  v2063004
# 24  Seasonally adjusted  Percent     239         units          0  v2063193
# 33  Seasonally adjusted  Percent     239         units          0  v2063382
# 42  Seasonally adjusted  Percent     239         units          0  v2063571
# 51  Seasonally adjusted  Percent     239         units          0  v2063760
# 60  Seasonally adjusted  Percent     239         units          0  v2063949
# 69  Seasonally adjusted  Percent     239         units          0  v2064138
# 78  Seasonally adjusted  Percent     239         units          0  v2064327
# 87  Seasonally adjusted  Percent     239         units          0  v2064516
# 96  Seasonally adjusted  Percent     239         units          0  v2064705
#
#       coordinate  value  status  symbol  terminated  decimals
# 6    1.7.1.1.1.1    8.2     NaN     NaN         NaN         1
# 15   2.7.1.1.1.1   12.9     NaN     NaN         NaN         1
# 24   3.7.1.1.1.1    9.7     NaN     NaN         NaN         1
# 33   4.7.1.1.1.1    8.4     NaN     NaN         NaN         1
# 42   5.7.1.1.1.1    8.9     NaN     NaN         NaN         1
# 51   6.7.1.1.1.1    6.7     NaN     NaN         NaN         1
# 60   7.7.1.1.1.1    9.4     NaN     NaN         NaN         1
# 69   8.7.1.1.1.1    7.2     NaN     NaN         NaN         1
# 78   9.7.1.1.1.1    6.3     NaN     NaN         NaN         1
# 87  10.7.1.1.1.1    8.8     NaN     NaN         NaN         1
# 96  11.7.1.1.1.1    7.0     NaN     NaN         NaN         1
# Processing file: C:\\Users\\bibis\\Desktop\\Dataset for capstone unemployment\April 2021_cleaned.csv
# Columns: ['ref_date', 'geo', 'age group', 'gender', 'value']
# Skipping file due to missing columns: C:\\Users\\bibis\\Desktop\\Dataset for capstone unemployment\April 2021_cleaned.csv
# Processing file: C:\\Users\\bibis\\Desktop\\Dataset for capstone unemployment\April 2022.csv
# Columns: ['REF_DATE', 'GEO', 'DGUID', 'Labour force characteristics', 'Gender', 'Age group', 'Statistics', 'Data type', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS']
# Unique values in 'labour force characteristics' column: ['Population' 'Labour force' 'Employment' 'Full-time employment'
#  'Part-time employment' 'Unemployment' 'Unemployment rate'
#  'Participation rate' 'Employment rate']
# Unique values in 'statistics' column: ['Estimate']
# Filtered data for C:\\Users\\bibis\\Desktop\\Dataset for capstone unemployment\April 2022.csv:
#    ref_date                        geo           dguid  \
# 6   2022-04                     Canada  2021A000011124
# 15  2022-04  Newfoundland and Labrador     2021A000210
# 24  2022-04       Prince Edward Island     2021A000211
# 33  2022-04                Nova Scotia     2021A000212
# 42  2022-04              New Brunswick     2021A000213
# 51  2022-04                     Quebec     2021A000224
# 60  2022-04                    Ontario     2021A000235
# 69  2022-04                   Manitoba     2021A000246
# 78  2022-04               Saskatchewan     2021A000247
# 87  2022-04                    Alberta     2021A000248
# 96  2022-04           British Columbia     2021A000259
#
#    labour force characteristics          gender          age group statistics  \
# 6             Unemployment rate  Total - Gender  15 years and over   Estimate
# 15            Unemployment rate  Total - Gender  15 years and over   Estimate
# 24            Unemployment rate  Total - Gender  15 years and over   Estimate
# 33            Unemployment rate  Total - Gender  15 years and over   Estimate
# 42            Unemployment rate  Total - Gender  15 years and over   Estimate
# 51            Unemployment rate  Total - Gender  15 years and over   Estimate
# 60            Unemployment rate  Total - Gender  15 years and over   Estimate
# 69            Unemployment rate  Total - Gender  15 years and over   Estimate
# 78            Unemployment rate  Total - Gender  15 years and over   Estimate
# 87            Unemployment rate  Total - Gender  15 years and over   Estimate
# 96            Unemployment rate  Total - Gender  15 years and over   Estimate
#
#               data type      uom  uom_id scalar_factor  scalar_id    vector  \
# 6   Seasonally adjusted  Percent     239         units          0  v2062815
# 15  Seasonally adjusted  Percent     239         units          0  v2063004
# 24  Seasonally adjusted  Percent     239         units          0  v2063193
# 33  Seasonally adjusted  Percent     239         units          0  v2063382
# 42  Seasonally adjusted  Percent     239         units          0  v2063571
# 51  Seasonally adjusted  Percent     239         units          0  v2063760
# 60  Seasonally adjusted  Percent     239         units          0  v2063949
# 69  Seasonally adjusted  Percent     239         units          0  v2064138
# 78  Seasonally adjusted  Percent     239         units          0  v2064327
# 87  Seasonally adjusted  Percent     239         units          0  v2064516
# 96  Seasonally adjusted  Percent     239         units          0  v2064705
#
#       coordinate  value  status  symbol  terminated  decimals
# 6    1.7.1.1.1.1    5.4     NaN     NaN         NaN         1
# 15   2.7.1.1.1.1   11.4     NaN     NaN         NaN         1
# 24   3.7.1.1.1.1    8.3     NaN     NaN         NaN         1
# 33   4.7.1.1.1.1    6.1     NaN     NaN         NaN         1
# 42   5.7.1.1.1.1    6.9     NaN     NaN         NaN         1
# 51   6.7.1.1.1.1    4.4     NaN     NaN         NaN         1
# 60   7.7.1.1.1.1    5.6     NaN     NaN         NaN         1
# 69   8.7.1.1.1.1
NaN     NaN         NaN         1
# 51   6.7.1.1.1.1    5.0     NaN     NaN         NaN         1
# 60   7.7.1.1.1.1    7.4     NaN     NaN         NaN         1
# 69   8.7.1.1.1.1    5.0     NaN     NaN         NaN         1
# 78   9.7.1.1.1.1    5.4     NaN     NaN         NaN         1
# 87  10.7.1.1.1.1    6.9     NaN     NaN         NaN         1
# 96  11.7.1.1.1.1    5.1     NaN     NaN         NaN         1
# Processing file: C:\\Users\\bibis\\Desktop\\Dataset for capstone unemployment\Jan 2022_cleaned.csv
# Columns: ['ref_date', 'geo', 'age group', 'gender', 'value']
# ...
# Processing file: C:\\Users\\bibis\\Desktop\\Dataset for capstone unemployment\Sep 2021.csv
# Columns: ['REF_DATE', 'GEO', 'DGUID', 'Labour force characteristics', 'Gender', 'Age group', 'Statistics', 'Data type', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS']
# Unique values in 'labour force characteristics' column: ['Population' 'Labour force' 'Employment' 'Full-time employment'
#  'Part-time employment' 'Unemployment' 'Unemployment rate'
#  'Participation rate' 'Employment rate']
# Unique values in 'statistics' column: ['Estimate']
# Filtered data for C:\\Users\\bibis\\Desktop\\Dataset for capstone unemployment\Sep 2021.csv:
#    ref_date                        geo           dguid  \
# 6   2021-09                     Canada  2021A000011124
# 15  2021-09  Newfoundland and Labrador     2021A000210
# 24  2021-09       Prince Edward Island     2021A000211
# 33  2021-09                Nova Scotia     2021A000212
# 42  2021-09              New Brunswick     2021A000213
# 51  2021-09                     Quebec     2021A000224
# 60  2021-09                    Ontario     2021A000235
# 69  2021-09                   Manitoba     2021A000246
# 78  2021-09               Saskatchewan     2021A000247
# 87  2021-09                    Alberta     2021A000248
# 96  2021-09           British Columbia     2021A000259
#
#    labour force characteristics          gender          age group statistics  \
# 6             Unemployment rate  Total - Gender  15 years and over   Estimate
# 15            Unemployment rate  Total - Gender  15 years and over   Estimate
# 24            Unemployment rate  Total - Gender  15 years and over   Estimate
# 33            Unemployment rate  Total - Gender  15 years and over   Estimate
# 42            Unemployment rate  Total - Gender  15 years and over   Estimate
# 51            Unemployment rate  Total - Gender  15 years and over   Estimate
# 60            Unemployment rate  Total - Gender  15 years and over   Estimate
# 69            Unemployment rate  Total - Gender  15 years and over   Estimate
# 78            Unemployment rate  Total - Gender  15 years and over   Estimate
# 87            Unemployment rate  Total - Gender  15 years and over   Estimate
# 96            Unemployment rate  Total - Gender  15 years and over   Estimate
#
#               data type      uom  uom_id scalar_factor  scalar_id    vector  \
# 6   Seasonally adjusted  Percent     239         units          0  v2062815
# 15  Seasonally adjusted  Percent     239         units          0  v2063004
# 24  Seasonally adjusted  Percent     239         units          0  v2063193
# 33  Seasonally adjusted  Percent     239         units          0  v2063382
# 42  Seasonally adjusted  Percent     239         units          0  v2063571
# 51  Seasonally adjusted  Percent     239         units          0  v2063760
# 60  Seasonally adjusted  Percent     239         units          0  v2063949
# 69  Seasonally adjusted  Percent     239         units          0  v2064138
# 78  Seasonally adjusted  Percent     239         units          0  v2064327
# 87  Seasonally adjusted  Percent     239         units          0  v2064516
# 96  Seasonally adjusted  Percent     239         units          0  v2064705
#
#       coordinate  value  status  symbol  terminated  decimals
# 6    1.7.1.1.1.1    7.0     NaN     NaN         NaN         1
# 15   2.7.1.1.1.1   14.0     NaN     NaN         NaN         1
# 24   3.7.1.1.1.1   11.5     NaN     NaN         NaN         1
# 33   4.7.1.1.1.1    7.9     NaN     NaN         NaN         1
# 42   5.7.1.1.1.1    9.6     NaN     NaN         NaN         1
# 51   6.7.1.1.1.1    5.9     NaN     NaN         NaN         1
# 60   7.7.1.1.1.1    7.4     NaN     NaN         NaN         1
# 69   8.7.1.1.1.1    5.7     NaN     NaN         NaN         1
# 78   9.7.1.1.1.1    6.4     NaN     NaN         NaN         1
# 87  10.7.1.1.1.1    7.8     NaN     NaN         NaN         1
# 96  11.7.1.1.1.1    6.2     NaN     NaN         NaN         1
# Processing file: C:\\Users\\bibis\\Desktop\\Dataset for capstone unemployment\Sep 2021_cleaned.csv
# Columns: ['ref_date', 'geo', 'age group', 'gender', 'value']
# Skipping file due to missing columns: C:\\Users\\bibis\\Desktop\\Dataset for capstone unemployment\Sep 2021_cleaned.csv
# Processing file: C:\\Users\\bibis\\Desktop\\Dataset for capstone unemployment\Sep 2023.csv
# Columns: ['REF_DATE', 'GEO', 'DGUID', 'Labour force characteristics', 'Gender', 'Age group', 'Statistics', 'Data type', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS']
# Unique values in 'labour force characteristics' column: ['Population' 'Labour force' 'Employment' 'Full-time employment'
#  'Part-time employment' 'Unemployment' 'Unemployment rate'
#  'Participation rate' 'Employment rate']
# Unique values in 'statistics' column: ['Estimate']
# Filtered data for C:\\Users\\bibis\\Desktop\\Dataset for capstone unemployment\Sep 2023.csv:
#    ref_date                        geo           dguid  \
# 6   2023-09                     Canada  2021A000011124
# 15  2023-09  Newfoundland and Labrador     2021A000210
# 24  2023-09       Prince Edward Island     2021A000211
# 33  2023-09                Nova Scotia     2021A000212
# 42  2023-09              New Brunswick     2021A000213
# 51  2023-09                     Quebec     2021A000224
# 60  2023-09                    Ontario     2021A000235
# 69  2023-09                   Manitoba     2021A000246
# 78  2023-09               Saskatchewan     2021A000247
# 87  2023-09                    Alberta     2021A000248
# 96  2023-09           British Columbia     2021A000259
#
#    labour force characteristics          gender          age group statistics  \
# 6             Unemployment rate  Total - Gender  15 years and over   Estimate
# 15            Unemployment rate  Total - Gender  15 years and over   Estimate
# 24            Unemployment rate  Total - Gender  15 years and over   Estimate
# 33            Unemployment rate  Total - Gender  15 years and over   Estimate
# 42            Unemployment rate  Total - Gender  15 years and over   Estimate
# 51            Unemployment rate  Total - Gender  15 years and over   Estimate
# 60            Unemployment rate  Total - Gender  15 years and over   Estimate
# 69            Unemployment rate  Total - Gender  15 years and over   Estimate
# 78            Unemployment rate  Total - Gender  15 years and over   Estimate
# 87            Unemployment rate  Total - Gender  15 years and over   Estimate
# 96            Unemployment rate  Total - Gender  15 years and over   Estimate
#
#               data type      uom  uom_id scalar_factor  scalar_id    vector  \
# 6   Seasonally adjusted  Percent     239         units          0  v2062815
# 15  Seasonally adjusted  Percent     239         units          0  v2063004
# 24  Seasonally adjusted  Percent     239         units          0  v2063193
# 33  Seasonally adjusted  Percent     239         units          0  v2063382
# 42  Seasonally adjusted  Percent     239         units          0  v2063571
# 51  Seasonally adjusted  Percent     239         units          0  v2063760
# 60  Seasonally adjusted  Percent     239         units          0  v2063949
# 69  Seasonally adjusted  Percent     239         units          0  v2064138
# 78  Seasonally adjusted  Percent     239         units          0  v2064327
# 87  Seasonally adjusted  Percent     239         units          0  v2064516
# 96  Seasonally adjusted  Percent     239         units          0  v2064705
#
#       coordinate  value  status  symbol  terminated  decimals
# 6    1.7.1.1.1.1    5.5     NaN     NaN         NaN         1
# 15   2.7.1.1.1.1    9.4     NaN     NaN         NaN         1
# 24   3.7.1.1.1.1    6.7     NaN     NaN         NaN         1
# 33   4.7.1.1.1.1    7.1     NaN     NaN         NaN         1
# 42   5.7.1.1.1.1    7.3     NaN     NaN         NaN         1
# 51   6.7.1.1.1.1    4.5     NaN     NaN         NaN         1
# 60   7.7.1.1.1.1    5.9     NaN     NaN         NaN         1
# 69   8.7.1.1.1.1    5.2     NaN     NaN         NaN         1
# 78   9.7.1.1.1.1    4.9     NaN     NaN         NaN         1
# 87  10.7.1.1.1.1    5.4     NaN     NaN         NaN         1
# 96  11.7.1.1.1.1    5.5     NaN     NaN         NaN         1
# Processing file: C:\\Users\\bibis\\Desktop\\Dataset for capstone unemployment\Sep 2023_cleaned.csv
# Columns: ['ref_date', 'geo', 'age group', 'gender', 'value']
# Skipping file due to missing columns: C:\\Users\\bibis\\Desktop\\Dataset for capstone unemployment\Sep 2023_cleaned.csv
# Processing file: C:\\Users\\bibis\\Desktop\\Dataset for capstone unemployment\September 2022.csv
# Columns: ['REF_DATE', 'GEO', 'DGUID', 'Labour force characteristics', 'Gender', 'Age group', 'Statistics', 'Data type', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS']
# Unique values in 'labour force characteristics' column: ['Population' 'Labour force' 'Employment' 'Full-time employment'
#  'Part-time employment' 'Unemployment' 'Unemployment rate'
#  'Participation rate' 'Employment rate']
# Unique values in 'statistics' column: ['Estimate']
# Filtered data for C:\\Users\\bibis\\Desktop\\Dataset for capstone unemployment\September 2022.csv:
#    ref_date                        geo           dguid  \
# 6   2022-09                     Canada  2021A000011124
# 15  2022-09  Newfoundland and Labrador     2021A000210
# 24  2022-09       Prince Edward Island     2021A000211
# 33  2022-09                Nova Scotia     2021A000212
# 42  2022-09              New Brunswick     2021A000213
# 51  2022-09                     Quebec     2021A000224
# 60  2022-09                    Ontario     2021A000235
# 69  2022-09                   Manitoba     2021A000246
# 78  2022-09               Saskatchewan     2021A000247
# 87  2022-09                    Alberta     2021A000248
# 96  2022-09           British Columbia     2021A000259
#
#    labour force characteristics          gender          age group statistics  \
# 6             Unemployment rate  Total - Gender  15 years and over   Estimate
# 15            Unemployment rate  Total - Gender  15 years and over   Estimate
# 24            Unemployment rate  Total - Gender  15 years and over   Estimate
# 33            Unemployment rate  Total - Gender  15 years and over   Estimate
# 42            Unemployment rate  Total - Gender  15 years and over   Estimate
# 51            Unemployment rate  Total - Gender  15 years and over   Estimate
# 60            Unemployment rate  Total - Gender  15 years and over   Estimate
# 69            Unemployment rate  Total - Gender  15 years and over   Estimate
# 78            Unemployment rate  Total - Gender  15 years and over   Estimate
# 87            Unemployment rate  Total - Gender  15 years and over   Estimate
# 96            Unemployment rate  Total - Gender  15 years and over   Estimate
#
#               data type      uom  uom_id scalar_factor  scalar_id    vector  \
# 6   Seasonally adjusted  Percent     239         units          0  v2062815
# 15  Seasonally adjusted  Percent     239         units          0  v2063004
# 24  Seasonally adjusted  Percent     239         units          0  v2063193
# 33  Seasonally adjusted  Percent     239         units          0  v2063382
# 42  Seasonally adjusted  Percent     239         units          0  v2063571
# 51  Seasonally adjusted  Percent     239         units          0  v2063760
# 60  Seasonally adjusted  Percent     239         units          0  v2063949
# 69  Seasonally adjusted  Percent     239         units          0  v2064138
# 78  Seasonally adjusted  Percent     239         units          0  v2064327
# 87  Seasonally adjusted  Percent     239         units          0  v2064516
# 96  Seasonally adjusted  Percent     239         units          0  v2064705
#
#       coordinate  value  status  symbol  terminated  decimals
# 6    1.7.1.1.1.1    5.1     NaN     NaN         NaN         1
# 15   2.7.1.1.1.1   10.0     NaN     NaN         NaN         1
# 24   3.7.1.1.1.1    8.8     NaN     NaN         NaN         1
# 33   4.7.1.1.1.1    6.2     NaN     NaN         NaN         1
# 42   5.7.1.1.1.1    6.5     NaN     NaN         NaN         1
# 51   6.7.1.1.1.1    4.4     NaN     NaN         NaN         1
# 60   7.7.1.1.1.1    5.5     NaN     NaN         NaN         1
# 69   8.7.1.1.1.1    4.6     NaN     NaN         NaN         1
# 78   9.7.1.1.1.1    4.3     NaN     NaN         NaN         1
# 87  10.7.1.1.1.1    5.4     NaN     NaN         NaN         1
# 96  11.7.1.1.1.1    4.4     NaN     NaN         NaN         1
# Processing file: C:\\Users\\bibis\\Desktop\\Dataset for capstone unemployment\September 2022_cleaned.csv
# Columns: ['ref_date', 'geo', 'age group', 'gender', 'value']
# Skipping file due to missing columns: C:\\Users\\bibis\\Desktop\\Dataset for capstone unemployment\September 2022_cleaned.csv
# Cleaned files: ['C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\April 2021_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\April 2022_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\April 2023_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\Aug 2022_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\August 2021_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\August 2023_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\Dec 2021_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\Dec 2022_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\Feb 2022_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\Feb 2023_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\Jan 2022_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\jan 2023_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\july 2021_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\July 2022_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\june 2021_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\June 2022_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\June 2023_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\march 2022_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\March 2023_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\May 2021_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\May 2022_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\May 2023_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\Nov 2021_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\Nov 2022_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\October 2021_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\October 2022_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\Sep 2021_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\Sep 2023_cleaned.csv', 'C:\\\\Users\\\\bibis\\\\Desktop\\\\Dataset for capstone unemployment\\September 2022_cleaned.csv']

# %%
import pandas as pd
import glob

# Path to the directory containing the cleaned CSV files
csv_directory = r"C:\\Users\\bibis\\Desktop\\Dataset for capstone unemployment"

# Get a list of all cleaned CSV files in the directory
cleaned_csv_files = glob.glob(csv_directory + '/*_cleaned.csv')

# Initialize an empty list to store DataFrames
data_frames = []

# Read each cleaned CSV file and append it to the list
for cleaned_csv in cleaned_csv_files:
    df = pd.read_csv(cleaned_csv)
    data_frames.append(df)

# Concatenate all DataFrames into a single DataFrame
merged_df = pd.concat(data_frames, ignore_index=True)

# Save the merged DataFrame to a new CSV file
merged_file_path = csv_directory + '\\merged_cleaned_data.csv'
merged_df.to_csv(merged_file_path, index=False)

print(f'Merged file saved as: {merged_file_path}')
# Out:
# Merged file saved as: C:\\Users\\bibis\\Desktop\\Dataset for capstone unemployment\merged_cleaned_data.csv
